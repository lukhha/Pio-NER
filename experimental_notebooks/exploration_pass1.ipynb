# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# df=pd.read_csv('/Users/lukishyadav/Desktop/engineering/case_studies/ner_casestudy/data/ner_dataset.csv',encoding='unicode_escape')

# %%
# Load the dataset with a specified encoding
file_path = '/Users/lukishyadav/Desktop/engineering/case_studies/ner_casestudy/data/ner_dataset.csv'  # Replace with your file path
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
# Display the first few rows of the dataset to understand its structure
print(data.head())
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
# # Drop rows with NaN values
data = data.dropna(subset=['Word','POS','Tag'])

# %%
data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
# Group the data by sentences
data['Sentence #'] = data['Sentence #'].ffill()  # Fill forward to propagate sentence IDs
sentences = data.groupby('Sentence #').apply(lambda s: [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(),
                                                                                     s['POS'].values.tolist(),
                                                                                     s['Tag'].values.tolist())])

# %%
# Convert the groupby object to a list of sentences
sentences = [s for s in sentences]

# %%
# Split the dataset into training, validation, and test sets (20% for test)
train_sentences, test_sentences = train_test_split(sentences, test_size=0.20, random_state=42)
train_sentences, val_sentences = train_test_split(train_sentences, test_size=0.25, random_state=42)  # 0.25 * 0.80 = 0.20

# %%
# Print the number of sentences in each split
print(f"Training sentences: {len(train_sentences)}")
print(f"Validation sentences: {len(val_sentences)}")
print(f"Test sentences: {len(test_sentences)}")
# Out:
# Training sentences: 28769
# Validation sentences: 9590
# Test sentences: 9590

# %%
# Extract words and tags from the sentences for training, validation, and test sets
def extract_words_tags(sentences):
    words = [[word for word, pos, tag in sentence] for sentence in sentences]
    tags = [[tag for word, pos, tag in sentence] for sentence in sentences]
    return words, tags

# %%
train_words, train_tags = extract_words_tags(train_sentences)
val_words, val_tags = extract_words_tags(val_sentences)
test_words, test_tags = extract_words_tags(test_sentences)

# %%
# Sample output
print(train_words[0])
print(train_tags[0])
# Out:
# ['Shortly', 'before', 'midday', 'local', 'time', 'Thursday', ',', 'the', 'torch', 'entered', 'Turin', 'through', 'the', 'Piazza', 'Massaua', '.']
# ['O', 'O', 'B-tim', 'O', 'B-tim', 'I-tim', 'O', 'O', 'O', 'O', 'B-org', 'O', 'O', 'B-geo', 'I-geo', 'O']

# %%
# Evaluation metrics: Precision, Recall, F1-score
from sklearn.metrics import classification_report

# %%
# Example baseline model (assigns 'O' to every word)
def baseline_model(words):
    return [['O'] * len(sentence) for sentence in words]

# %%
# Evaluate the baseline model
baseline_predictions = baseline_model(test_words)
print(classification_report([tag for sentence in test_tags for tag in sentence],
                            [tag for sentence in baseline_predictions for tag in sentence]))
# Out:
# /opt/anaconda3/envs/gen_3.8/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        B-art       0.00      0.00      0.00        72
#        B-eve       0.00      0.00      0.00        74
#        B-geo       0.00      0.00      0.00      7481
#        B-gpe       0.00      0.00      0.00      3196
#        B-nat       0.00      0.00      0.00        40
#        B-org       0.00      0.00      0.00      3962
#        B-per       0.00      0.00      0.00      3370
#        B-tim       0.00      0.00      0.00      3986
#        I-art       0.00      0.00      0.00        43
#        I-eve       0.00      0.00      0.00        69
#        I-geo       0.00      0.00      0.00      1486
#        I-gpe       0.00      0.00      0.00        49
#        I-nat       0.00      0.00      0.00        19
#        I-org       0.00      0.00      0.00      3311
#        I-per       0.00      0.00      0.00      3337
#        I-tim       0.00      0.00      0.00      1324
#            O       0.85      1.00      0.92    177485
#
#     accuracy                           0.85    209304
#    macro avg       0.05      0.06      0.05    209304
# weighted avg       0.72      0.85      0.78    209304
# /opt/anaconda3/envs/gen_3.8/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/gen_3.8/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Shortcomings: baseline model assigns 'O' to every word, leading to poor precision, recall, and F1-score

# %%
# Improved model (using Conditional Random Fields - CRF)
import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %%
# Feature extraction function
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features

# %%
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for word, postag, label in sent]

# %%
# Extract features and labels for training and testing
X_train = [sent2features(s) for s in train_sentences]
y_train = [sent2labels(s) for s in train_sentences]
X_val = [sent2features(s) for s in val_sentences]
y_val = [sent2labels(s) for s in val_sentences]
X_test = [sent2features(s) for s in test_sentences]
y_test = [sent2labels(s) for s in test_sentences]

# %%
# %time
# Train the CRF model
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=False
)

crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     max_iterations=100)

# %%
# Make predictions using the CRF model
y_pred = crf.predict(X_test)

# %%
# Evaluate the CRF model
print(metrics.flat_classification_report(y_test, y_pred, labels=crf.classes_, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            O      0.992     0.994     0.993    177485
#        B-tim      0.918     0.879     0.898      3986
#        I-tim      0.829     0.740     0.782      1324
#        B-org      0.789     0.739     0.763      3962
#        B-geo      0.859     0.902     0.880      7481
#        I-geo      0.825     0.788     0.806      1486
#        B-gpe      0.966     0.939     0.952      3196
#        B-per      0.849     0.825     0.837      3370
#        I-per      0.850     0.892     0.871      3337
#        B-nat      0.562     0.225     0.321        40
#        I-org      0.799     0.797     0.798      3311
#        I-gpe      0.862     0.510     0.641        49
#        B-art      0.500     0.194     0.280        72
#        I-art      0.429     0.140     0.211        43
#        B-eve      0.521     0.338     0.410        74
#        I-nat      1.000     0.158     0.273        19
#        I-eve      0.472     0.246     0.324        69
#
#     accuracy                          0.971    209304
#    macro avg      0.766     0.606     0.649    209304
# weighted avg      0.971     0.971     0.971    209304

# %%
# Future scope: 
# - Experiment with different feature sets
# - Use deep learning models such as BiLSTM-CRF or BERT
# - Fine-tune hyperparameters of the CRF model

# %%
train_sentences
# Out:
# [[('Shortly', 'RB', 'O'),
#   ('before', 'IN', 'O'),
#   ('midday', 'NN', 'B-tim'),
#   ('local', 'JJ', 'O'),
#   ('time', 'NN', 'B-tim'),
#   ('Thursday', 'NNP', 'I-tim'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('torch', 'NN', 'O'),
#   ('entered', 'VBD', 'O'),
#   ('Turin', 'NNP', 'B-org'),
#   ('through', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Piazza', 'NNP', 'B-geo'),
#   ('Massaua', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('There', 'EX', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('global', 'JJ', 'O'),
#   ('shift', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('dietary', 'JJ', 'O'),
#   ('habits', 'NNS', 'O'),
#   ('towards', 'IN', 'O'),
#   ('calorie', 'NN', 'O'),
#   ('rich', 'JJ', 'O'),
#   ('foods', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('as', 'RB', 'O'),
#   ('well', 'RB', 'O'),
#   ('as', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('universal', 'JJ', 'O'),
#   ('decrease', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('exercise', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('attack', 'NN', 'O'),
#   ('took', 'VBD', 'O'),
#   ('place', 'NN', 'O'),
#   ('near', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('gate', 'NN', 'O'),
#   ('into', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('capital', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('heavily', 'RB', 'O'),
#   ('fortified', 'VBN', 'O'),
#   ('Green', 'NNP', 'B-geo'),
#   ('Zone', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('most', 'RBS', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('government', 'NN', 'O'),
#   ('offices', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('located', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('Thick', 'NNP', 'O'),
#   ('smoke', 'NN', 'O'),
#   ('filled', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('air', 'NN', 'O'),
#   ('as', 'IN', 'O'),
#   ('helicopters', 'NNS', 'O'),
#   ('flew', 'VBD', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('area', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Thursday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('Treasury', 'NNP', 'B-org'),
#   ('Secretary', 'NNP', 'O'),
#   ('Timothy', 'NNP', 'B-per'),
#   ('Geithner', 'NNP', 'I-per'),
#   ('urged', 'VBD', 'O'),
#   ('Congress', 'NNP', 'B-org'),
#   ('to', 'TO', 'O'),
#   ('approve', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('administration', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('plan', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('expand', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('powers', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('monitor', 'VB', 'O'),
#   ('large', 'JJ', 'O'),
#   ('financial', 'JJ', 'O'),
#   ('firms', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('rescue', 'NN', 'O'),
#   ('operation', 'NN', 'O'),
#   ('continued', 'VBD', 'O'),
#   ('into', 'IN', 'O'),
#   ('the', 'DT', 'B-tim'),
#   ('night', 'NN', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Swaziland', 'NNP', 'B-gpe'),
#   ('recently', 'RB', 'O'),
#   ('surpassed', 'VBD', 'O'),
#   ('Botswana', 'NNP', 'B-gpe'),
#   ('as', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('highest', 'JJS', 'O'),
#   ('known', 'VBN', 'O'),
#   ('HIV', 'NNP', 'B-nat'),
#   ('/', 'CC', 'O'),
#   ('AIDS', 'NNP', 'B-nat'),
#   ('prevalence', 'NN', 'O'),
#   ('rate', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Last', 'JJ', 'O'),
#   ('year', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Afghan', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Hamid', 'NNP', 'I-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('offered', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('olive', 'JJ', 'O'),
#   ('branch', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('rank-and-file', 'JJ', 'O'),
#   ('Taleban', 'NNP', 'B-org'),
#   ('fighters', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('inviting', 'VBG', 'O'),
#   ('them', 'PRP', 'O'),
#   ('to', 'TO', 'O'),
#   ('join', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('political', 'JJ', 'O'),
#   ('process', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Pakistani', 'JJ', 'B-gpe'),
#   ('military', 'NN', 'O'),
#   ('launched', 'VBD', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('offensive', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Orakzai', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('hunt', 'VB', 'O'),
#   ('Taliban', 'NNP', 'B-org'),
#   ('insurgents', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('announcement', 'NN', 'O'),
#   ('comes', 'VBZ', 'O'),
#   ('hours', 'NNS', 'O'),
#   ('after', 'IN', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('al-Assad', 'NNP', 'B-geo'),
#   ('held', 'VBD', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('Egyptian', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Hosni', 'NNP', 'I-per'),
#   ('Mubarak', 'NNP', 'I-per'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Syrian', 'JJ', 'B-gpe'),
#   ('capital', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('July', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('prominent', 'JJ', 'O'),
#   ('Somali', 'JJ', 'B-gpe'),
#   ('peace', 'NN', 'O'),
#   ('activist', 'NN', 'O'),
#   ('Abdulkadir', 'NNP', 'B-org'),
#   ('Yahya', 'NNP', 'I-org'),
#   ('Ali', 'NNP', 'I-org'),
#   ('was', 'VBD', 'O'),
#   ('gunned', 'VBN', 'O'),
#   ('down', 'RP', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('capital', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Mogadishu', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Because', 'IN', 'O'),
#   ('of', 'IN', 'O'),
#   ('traditionally', 'RB', 'O'),
#   ('close', 'JJ', 'O'),
#   ('links', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('US', 'NNP', 'B-org'),
#   ('Virgin', 'NNP', 'I-org'),
#   ('Islands', 'NNP', 'I-org'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('Virgin', 'NNP', 'B-org'),
#   ('Islands', 'NNP', 'I-org'),
#   ('has', 'VBZ', 'O'),
#   ('used', 'VBN', 'O'),
#   ('the', 'DT', 'O'),
#   ('US', 'NNP', 'B-org'),
#   ('dollar', 'NN', 'O'),
#   ('as', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('currency', 'NN', 'O'),
#   ('since', 'IN', 'B-tim'),
#   ('1959', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('rebels', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('who', 'WP', 'O'),
#   ('claim', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('be', 'VB', 'O'),
#   ('inspired', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('Chinese', 'JJ', 'B-gpe'),
#   ('revolutionary', 'JJ', 'O'),
#   ('Mao', 'NNP', 'B-per'),
#   ('Zedong', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('fighting', 'VBG', 'O'),
#   ('since', 'IN', 'O'),
#   ('1996', 'CD', 'B-tim'),
#   ('to', 'TO', 'O'),
#   ('replace', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('constitutional', 'JJ', 'O'),
#   ('monarchy', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('only', 'JJ', 'O'),
#   ('Hindu', 'NNP', 'B-geo'),
#   ('kingdom', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('communist', 'JJ', 'O'),
#   ('state', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('renegotiated', 'VBN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('double', 'JJ', 'O'),
#   ('taxation', 'NN', 'O'),
#   ('agreements', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('numerous', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('US', 'NNP', 'B-org'),
#   (',', ',', 'O'),
#   ('to', 'TO', 'O'),
#   ('incorporate', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('OECD', 'NNP', 'B-geo'),
#   ('standard', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('it', 'PRP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('working', 'VBG', 'O'),
#   ('with', 'IN', 'O'),
#   ('Germany', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('UK', 'NNP', 'B-org'),
#   ('to', 'TO', 'O'),
#   ('resolve', 'VB', 'O'),
#   ('outstanding', 'JJ', 'O'),
#   ('issues', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('particularly', 'RB', 'O'),
#   ('the', 'DT', 'O'),
#   ('possibility', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('imposing', 'VBG', 'O'),
#   ('taxes', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('bank', 'NN', 'O'),
#   ('deposits', 'NNS', 'O'),
#   ('held', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('foreigners', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Saudi', 'JJ', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('security', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('suspected', 'JJ', 'O'),
#   ('militant', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('western', 'JJ', 'O'),
#   ('city', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Jeddah', 'NNP', 'B-geo'),
#   ('after', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('man', 'NN', 'O'),
#   ('tried', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('use', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('hand', 'NN', 'O'),
#   ('grenade', 'NN', 'O'),
#   ('against', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('.', '.', 'O')],
#  [('Government', 'NN', 'O'),
#   ('corruption', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('also', 'RB', 'O'),
#   ('hindering', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('development', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('healthy', 'JJ', 'O'),
#   ('private', 'JJ', 'O'),
#   ('sector', 'NN', 'O'),
#   ('as', 'IN', 'O'),
#   ('companies', 'NNS', 'O'),
#   ('seek', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('navigate', 'VB', 'O'),
#   ('an', 'DT', 'O'),
#   ('environment', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('ever-changing', 'JJ', 'O'),
#   ('rules', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('spokesman', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Modena', 'NNP', 'B-geo'),
#   ('Polyclinic', 'NNP', 'I-geo'),
#   ('says', 'VBZ', 'O'),
#   ('Pavarotti', 'NNP', 'B-per'),
#   ('was', 'VBD', 'O'),
#   ('admitted', 'VBN', 'O'),
#   ('earlier', 'RBR', 'O'),
#   ('this', 'DT', 'O'),
#   ('week', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Philippine', 'JJ', 'B-org'),
#   ('Senator', 'NNP', 'B-per'),
#   ('Benigno', 'NNP', 'B-org'),
#   ('Aquino', 'NNP', 'I-org'),
#   ('III', 'NNP', 'I-org'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('formally', 'RB', 'O'),
#   ('declared', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('winner', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Other', 'JJ', 'O'),
#   ('terrorist', 'JJ', 'O'),
#   ('attacks', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('blamed', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('Islamic', 'NNP', 'O'),
#   ('terrorists', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Separately', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('witnesses', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('soldiers', 'NNS', 'O'),
#   ('shot', 'VBD', 'O'),
#   ('and', 'CC', 'O'),
#   ('killed', 'VBD', 'O'),
#   ('another', 'DT', 'O'),
#   ('Hamas', 'NNP', 'B-org'),
#   ('militant', 'NN', 'O'),
#   ('near', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Rafah', 'NNP', 'B-geo'),
#   ('refugee', 'NN', 'O'),
#   ('camp', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('deadlocked', 'JJ', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('threatening', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('further', 'RB', 'O'),
#   ('disrupt', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('already', 'RB', 'O'),
#   ('shaky', 'JJ', 'O'),
#   ('truce', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Police', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('troops', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('deployed', 'VBN', 'O'),
#   ('days', 'NNS', 'O'),
#   ('ahead', 'RB', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('ceremony', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('during', 'IN', 'O'),
#   ('which', 'WDT', 'O'),
#   ('351', 'CD', 'O'),
#   ('new', 'JJ', 'O'),
#   ('lawmakers', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('sworn', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('by', 'IN', 'O'),
#   ('President', 'NNP', 'B-per'),
#   ('Hamid', 'NNP', 'I-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Softball', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('better', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('baseball', 'NN', 'O'),
#   ('because', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Seventh', 'NNP', 'B-org'),
#   ('Inning', 'NNP', 'I-org'),
#   ('Stretch', 'NNP', 'I-org'),
#   ('means', 'VBZ', 'O'),
#   ('stand', 'VB', 'O'),
#   ('up', 'RP', 'O'),
#   ('and', 'CC', 'O'),
#   ('go', 'VB', 'O'),
#   ('home', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('leading', 'VBG', 'O'),
#   ('Muslim', 'NNP', 'B-org'),
#   ('scholars', 'NNS', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('sent', 'VBN', 'O'),
#   ('holiday', 'NN', 'O'),
#   ('greetings', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('Christians', 'NNPS', 'O'),
#   ('worldwide', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('Caracas', 'NNP', 'B-tim'),
#   ('Monday', 'NNP', 'I-tim'),
#   (',', ',', 'O'),
#   ('legislators', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('ruling', 'VBG', 'O'),
#   ('party', 'NN', 'O'),
#   ('pushed', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('appointments', 'NNS', 'O'),
#   ('through', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('165-seat', 'JJ', 'O'),
#   ('Congress', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('Indian', 'JJ', 'B-gpe'),
#   ('families', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('begun', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('bury', 'VB', 'O'),
#   ('relatives', 'NNS', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('series', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('bomb', 'NN', 'O'),
#   ('blasts', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('western', 'JJ', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('as', 'IN', 'O'),
#   ('security', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('patrol', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('avoid', 'VB', 'O'),
#   ('further', 'JJ', 'O'),
#   ('violence', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Also', 'RB', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('reported', 'VBD', 'O'),
#   ('that', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('fourth', 'JJ', 'O'),
#   ('American', 'NNP', 'B-org'),
#   ('died', 'VBD', 'O'),
#   ('from', 'IN', 'O'),
#   ('injuries', 'NNS', 'O'),
#   ('suffered', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('attacks', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('raising', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('death', 'NN', 'O'),
#   ('toll', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('58', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Worries', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('large', 'JJ', 'O'),
#   ('banks', 'NNS', 'O'),
#   ('might', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('be', 'VB', 'O'),
#   ('strong', 'JJ', 'O'),
#   ('enough', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('cope', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('deepening', 'VBG', 'O'),
#   ('recession', 'NN', 'O'),
#   ('prompted', 'VBD', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('institute', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('series', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('"', '``', 'O'),
#   ('stress', 'NN', 'O'),
#   ('tests', 'NNS', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('The', 'DT', 'O'),
#   ('2010', 'CD', 'B-tim'),
#   ('Poverty', 'NN', 'O'),
#   ('Assessment', 'NN', 'O'),
#   ('shows', 'VBZ', 'O'),
#   ('that', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('4', 'CD', 'O'),
#   ('out', 'IN', 'O'),
#   ('of', 'IN', 'O'),
#   ('10', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('live', 'VBP', 'O'),
#   ('in', 'IN', 'O'),
#   ('poverty', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('New', 'NNP', 'B-org'),
#   ('Horizons', 'NNP', 'I-org'),
#   ('probe', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('photograph', 'VB', 'O'),
#   ('Pluto', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('gather', 'VB', 'O'),
#   ('data', 'NNS', 'O'),
#   ('about', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('atmosphere', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('surface', 'NN', 'O'),
#   ('geology', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('temperature', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Police', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('trying', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('determine', 'VB', 'O'),
#   ('whether', 'IN', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Olmert', 'NNP', 'I-per'),
#   ('gave', 'VBD', 'O'),
#   ('any', 'DT', 'O'),
#   ('favors', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('businessman', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('payments', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('1954', 'CD', 'B-tim'),
#   (',', ',', 'O'),
#   ('Curacao', 'NNP', 'B-org'),
#   ('and', 'CC', 'O'),
#   ('several', 'JJ', 'O'),
#   ('other', 'JJ', 'O'),
#   ('Dutch', 'JJ', 'B-gpe'),
#   ('Caribbean', 'NNP', 'B-geo'),
#   ('possessions', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('reorganized', 'VBN', 'O'),
#   ('as', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Netherlands', 'NNP', 'B-geo'),
#   ('Antilles', 'NNPS', 'I-geo'),
#   (',', ',', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Kingdom', 'NNP', 'B-org'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Netherlands', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('trial', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('former', 'JJ', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('leader', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('six', 'CD', 'O'),
#   ('co-defendants', 'NNS', 'O'),
#   ('involves', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('so-called', 'JJ', 'O'),
#   ('Anfal', 'NNP', 'O'),
#   ('campaign', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('upsurge', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('violence', 'NN', 'O'),
#   ('comes', 'VBZ', 'O'),
#   ('amid', 'IN', 'O'),
#   ('threats', 'NNS', 'O'),
#   ('that', 'WDT', 'O'),
#   ('Tamil', 'NNP', 'B-org'),
#   ('rebels', 'NNS', 'O'),
#   ('may', 'MD', 'O'),
#   ('resume', 'VB', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('violent', 'JJ', 'O'),
#   ('struggle', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('independent', 'JJ', 'O'),
#   ('Tamil', 'NN', 'B-org'),
#   ('homeland', 'NN', 'O'),
#   ('if', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('fails', 'VBZ', 'O'),
#   ('to', 'TO', 'O'),
#   ('agree', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('peace', 'NN', 'O'),
#   ('settlement', 'NN', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('next', 'JJ', 'O'),
#   ('12', 'CD', 'B-tim'),
#   ('months', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Obama', 'NNP', 'B-per'),
#   ('is', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('candidate', 'NN', 'O'),
#   ('best', 'RB', 'O'),
#   ('able', 'JJ', 'O'),
#   ('to', 'TO', 'O'),
#   ('solve', 'VB', 'O'),
#   ('these', 'DT', 'O'),
#   ('problems', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('bring', 'VB', 'O'),
#   ('change', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('America', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('plan', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('meet', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('leaders', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Pakistani', 'JJ', 'B-gpe'),
#   ('Kashmir', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Pakistan-based', 'JJ', 'O'),
#   ('rebel', 'NN', 'O'),
#   ('groups', 'NNS', 'O'),
#   ('which', 'WDT', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('involved', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('violent', 'JJ', 'O'),
#   ('insurgency', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Indian', 'JJ', 'B-gpe'),
#   ('Kashmir', 'NNP', 'B-geo'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('past', 'JJ', 'B-tim'),
#   ('15', 'CD', 'I-tim'),
#   ('years', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Pakistani', 'JJ', 'B-gpe'),
#   ('authorities', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('released', 'VBN', 'O'),
#   ('an', 'DT', 'O'),
#   ('alleged', 'JJ', 'O'),
#   ('al-Qaida', 'NNP', 'B-org'),
#   ('militant', 'NN', 'O'),
#   ('accused', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('involvement', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('bomb', 'NN', 'O'),
#   ('attack', 'NN', 'O'),
#   ('against', 'IN', 'O'),
#   ('former', 'JJ', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'O'),
#   ('Benazir', 'NNP', 'B-per'),
#   ('Bhutto', 'NNP', 'I-per'),
#   ('last', 'JJ', 'O'),
#   ('year', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Meanwhile', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('son', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Hariri', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('Saad', 'NNP', 'B-per'),
#   ('Hariri', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('called', 'VBD', 'O'),
#   ('for', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('international', 'JJ', 'O'),
#   ('tribunal', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('punish', 'VB', 'O'),
#   ('those', 'DT', 'O'),
#   ('responsible', 'JJ', 'O'),
#   ('for', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('father', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('assassination', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mexican', 'JJ', 'B-gpe'),
#   ('federal', 'JJ', 'O'),
#   ('police', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('have', 'VBP', 'O'),
#   ('captured', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('regional', 'JJ', 'O'),
#   ('leader', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Zetas', 'NNP', 'B-org'),
#   ('drug', 'NN', 'O'),
#   ('gang', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('who', 'WP', 'O'),
#   ('allegedly', 'RB', 'O'),
#   ('trafficked', 'VBD', 'O'),
#   ('drugs', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Dominican', 'NNP', 'B-geo'),
#   ('Republic', 'NNP', 'I-geo'),
#   ('and', 'CC', 'O'),
#   ('Panama', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('WFP', 'NNP', 'B-org'),
#   ('announced', 'VBD', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('that', 'IN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('help', 'VB', 'O'),
#   ('feed', 'VB', 'O'),
#   ('about', 'IN', 'O'),
#   ('two', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('cost', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('$', '$', 'O'),
#   ('6', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('seized', 'VBN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('by', 'IN', 'O'),
#   ('six', 'CD', 'O'),
#   ('gunmen', 'NNS', 'O'),
#   ('near', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('southern', 'JJ', 'O'),
#   ('city', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Warri', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Literature', 'NNP', 'B-org'),
#   ('Prize', 'NNP', 'I-org'),
#   ('winner', 'NN', 'I-org'),
#   ('Harold', 'NNP', 'I-org'),
#   ('Pinter', 'NNP', 'I-org'),
#   ('will', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('attend', 'VB', 'O'),
#   ('because', 'IN', 'O'),
#   ('of', 'IN', 'O'),
#   ('health', 'NN', 'O'),
#   ('problems', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Egeland', 'NNP', 'I-per'),
#   ('told', 'VBD', 'O'),
#   ('reporters', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('U.N.', 'NNP', 'B-geo'),
#   ('headquarters', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Geneva', 'NNP', 'B-geo'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('that', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('rising', 'VBG', 'O'),
#   ('violence', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Darfur', 'NNP', 'B-geo'),
#   ('region', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('put', 'VBN', 'O'),
#   ('aid', 'NN', 'O'),
#   ('workers', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('risk', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Irish', 'JJ', 'B-gpe'),
#   ('authorities', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('investigating', 'VBG', 'O'),
#   ('whether', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('second', 'JJ', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('woman', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('involved', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('plot', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('kill', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('Swedish', 'JJ', 'B-gpe'),
#   ('cartoonist', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('drawing', 'VBG', 'O'),
#   ('an', 'DT', 'O'),
#   ('image', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Prophet', 'NNP', 'B-per'),
#   ('Muhammad', 'NNP', 'I-per'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('body', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('dog', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('She', 'PRP', 'O'),
#   ('co-founded', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('National', 'NNP', 'B-org'),
#   ('Organization', 'NNP', 'I-org'),
#   ('for', 'IN', 'I-org'),
#   ('Women', 'NNP', 'I-org'),
#   ('in', 'IN', 'O'),
#   ('1966', 'CD', 'B-tim'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('National', 'NNP', 'B-org'),
#   ('Political', 'NNP', 'I-org'),
#   ('Women', 'NNP', 'I-org'),
#   ("'s", 'POS', 'I-org'),
#   ('Caucus', 'NNP', 'I-org'),
#   ('in', 'IN', 'O'),
#   ('1971', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Leftist', 'JJ', 'O'),
#   ('former', 'JJ', 'O'),
#   ('Mexico', 'NNP', 'B-gpe'),
#   ('City', 'NNP', 'I-gpe'),
#   ('Mayor', 'NNP', 'B-per'),
#   ('Andres', 'NNP', 'I-per'),
#   ('Manuel', 'NNP', 'I-per'),
#   ('Lopez', 'NNP', 'I-per'),
#   ('Obrador', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('kicked', 'VBN', 'O'),
#   ('off', 'RP', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('campaign', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('next', 'JJ', 'O'),
#   ('year', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('France', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('lower', 'JJR', 'O'),
#   ('house', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('parliament', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('approved', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('new', 'JJ', 'O'),
#   ('anti-terrorism', 'JJ', 'O'),
#   ('bill', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('includes', 'VBZ', 'O'),
#   ('increasing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('use', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('video', 'NN', 'O'),
#   ('surveillance', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe'),
#   ('police', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('arrested', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('two', 'CD', 'O'),
#   ('suspects', 'NNS', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('and', 'CC', 'O'),
#   ('recovered', 'VBD', 'O'),
#   ('millions', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('dollars', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('bank', 'NN', 'O'),
#   ('robbery', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('left', 'VBD', 'O'),
#   ('eight', 'CD', 'O'),
#   ('guards', 'NNS', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('Iran', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('state-run', 'JJ', 'O'),
#   ('media', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('president', 'NN', 'O'),
#   ('discussed', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('octopus', 'NN', 'O'),
#   ('during', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('speech', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('youth', 'NN', 'O'),
#   ('festival', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Tehran', 'NNP', 'B-geo'),
#   ('on', 'IN', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Five', 'CD', 'O'),
#   ('more', 'JJR', 'O'),
#   ('Marines', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('same', 'JJ', 'O'),
#   ('unit', 'NN', 'O'),
#   ('were', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('ambush', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('died', 'VBD', 'O'),
#   ('at', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('Jakarta', 'NNP', 'B-geo'),
#   ('hospital', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('bird', 'NN', 'O'),
#   ('flu', 'NN', 'O'),
#   ('patients', 'NNS', 'O'),
#   ('April', 'NNP', 'B-tim'),
#   ('26', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('film', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('opening', 'VBG', 'O'),
#   ('in', 'IN', 'O'),
#   ('India', 'NNP', 'B-geo'),
#   ('a', 'DT', 'O'),
#   ('week', 'NN', 'O'),
#   ('later', 'RB', 'B-tim'),
#   ('than', 'IN', 'O'),
#   ('originally', 'RB', 'O'),
#   ('planned', 'VBN', 'O'),
#   ('because', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('distributors', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('India', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('censorship', 'NN', 'O'),
#   ('board', 'NN', 'O'),
#   ('could', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('agree', 'VB', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('wording', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('placement', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('disclaimer', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('African', 'NNP', 'B-org'),
#   ('Union', 'NNP', 'I-org'),
#   ("'s", 'POS', 'I-org'),
#   ('Peace', 'NNP', 'I-org'),
#   ('and', 'CC', 'I-org'),
#   ('Security', 'NNP', 'I-org'),
#   ('Council', 'NNP', 'I-org'),
#   ('has', 'VBZ', 'O'),
#   ('affirmed', 'VBN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('continuing', 'VBG', 'O'),
#   ('support', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('deployment', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('United', 'NNP', 'B-org'),
#   ('Nations', 'NNP', 'I-org'),
#   ('peacekeepers', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Sudan', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('violence-plagued', 'JJ', 'O'),
#   ('Darfur', 'NNP', 'O'),
#   ('region', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Islamist', 'NNP', 'O'),
#   ('insurgents', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('waged', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('bloody', 'JJ', 'O'),
#   ('17-month', 'JJ', 'O'),
#   ('battle', 'NN', 'O'),
#   ('against', 'IN', 'O'),
#   ('Somalia', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Ethiopian-backed', 'JJ', 'O'),
#   ('interim', 'JJ', 'O'),
#   ('government', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Dollar-priced', 'JJ', 'O'),
#   ('raw', 'JJ', 'O'),
#   ('materials', 'NNS', 'O'),
#   ('like', 'IN', 'O'),
#   ('oil', 'NN', 'O'),
#   ('gain', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('weak', 'JJ', 'O'),
#   ('greenback', 'NN', 'O'),
#   ('because', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('fall', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('dollar', 'NN', 'O'),
#   ('makes', 'VBZ', 'O'),
#   ('them', 'PRP', 'O'),
#   ('cheaper', 'JJR', 'O'),
#   ('for', 'IN', 'O'),
#   ('buyers', 'NNS', 'O'),
#   ('using', 'VBG', 'O'),
#   ('other', 'JJ', 'O'),
#   (',', ',', 'O'),
#   ('stronger', 'JJR', 'O'),
#   ('currencies', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Israel', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('are', 'VBP', 'O'),
#   ('worried', 'VBN', 'O'),
#   ('Hamas', 'NNP', 'B-org'),
#   ('will', 'MD', 'O'),
#   ('do', 'VB', 'O'),
#   ('well', 'RB', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('January', 'NNP', 'B-tim'),
#   ('poll', 'NN', 'I-tim'),
#   (',', ',', 'O'),
#   ('threatening', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('peace', 'NN', 'O'),
#   ('process', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('An', 'DT', 'O'),
#   ('investigation', 'NN', 'O'),
#   ('team', 'NN', 'O'),
#   ('made', 'VBN', 'O'),
#   ('up', 'IN', 'O'),
#   ('of', 'IN', 'O'),
#   ('experts', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('WHO', 'NNP', 'B-org'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('Congolese', 'JJ', 'B-gpe'),
#   ('government', 'NN', 'O'),
#   ('have', 'VBP', 'O'),
#   ('arrived', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('central', 'JJ', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('where', 'WRB', 'O'),
#   ('the', 'DT', 'O'),
#   ('outbreak', 'NN', 'O'),
#   ('began', 'VBD', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('requires', 'VBZ', 'O'),
#   ('Venezuelans', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('act', 'VB', 'O'),
#   ('as', 'IN', 'O'),
#   ('informants', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('secret', 'JJ', 'O'),
#   ('police', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('community', 'NN', 'O'),
#   ('monitoring', 'NN', 'O'),
#   ('groups', 'NNS', 'O'),
#   ('loyal', 'JJ', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('president', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('President', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('plans', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('help', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('program', 'NN', 'O'),
#   ('avoid', 'VB', 'O'),
#   ('severe', 'JJ', 'O'),
#   ('funding', 'NN', 'O'),
#   ('shortfalls', 'NNS', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('next', 'JJ', 'O'),
#   ('few', 'JJ', 'B-tim'),
#   ('decades', 'NNS', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Pakistan', 'NNP', 'B-geo'),
#   ('already', 'RB', 'O'),
#   ('was', 'VBD', 'O'),
#   ('working', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('pay', 'VB', 'O'),
#   ('back', 'RB', 'O'),
#   ('an', 'DT', 'O'),
#   ('$', '$', 'O'),
#   ('11', 'CD', 'O'),
#   ('billion', 'CD', 'O'),
#   ('loan', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('IMF', 'NNP', 'B-org'),
#   ('that', 'WDT', 'O'),
#   ('was', 'VBD', 'O'),
#   ('helping', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('nation', 'NN', 'O'),
#   ('cope', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('global', 'JJ', 'O'),
#   ('economic', 'JJ', 'O'),
#   ('crisis', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Also', 'RB', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('video', 'NN', 'O'),
#   ('dated', 'VBN', 'O'),
#   ('September', 'NNP', 'B-tim'),
#   ('12', 'CD', 'I-tim'),
#   ('was', 'VBD', 'O'),
#   ('posted', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Internet', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('attributed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('Ansar', 'NNP', 'B-geo'),
#   ('al-Sunna', 'NNP', 'I-geo'),
#   ('militant', 'NN', 'O'),
#   ('group', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('soldier', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('wounded', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('An', 'DT', 'O'),
#   ('August', 'NNP', 'B-tim'),
#   ('31', 'CD', 'I-tim'),
#   ('U.N.', 'NNP', 'B-org'),
#   ('Security', 'NNP', 'I-org'),
#   ('Council', 'NNP', 'I-org'),
#   ('deadline', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('Iran', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('halt', 'VB', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('nuclear', 'JJ', 'O'),
#   ('activities', 'NNS', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('also', 'RB', 'O'),
#   ('weighing', 'VBG', 'O'),
#   ('heavily', 'RB', 'O'),
#   ('on', 'IN', 'O'),
#   ('oil', 'NN', 'O'),
#   ('prices', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('report', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('operation', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('designed', 'VBN', 'O'),
#   ('as', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('follow-up', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('"', '``', 'O'),
#   ('Restore', 'NNP', 'O'),
#   ('Order', 'NNP', 'O'),
#   (',', ',', 'O'),
#   ('"', '``', 'O'),
#   ('when', 'WRB', 'O'),
#   ('Zimbabwe', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('government', 'NN', 'O'),
#   ('destroyed', 'VBD', 'O'),
#   ('unauthorized', 'JJ', 'O'),
#   ('dwellings', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('market', 'NN', 'O'),
#   ('stalls', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('what', 'WP', 'O'),
#   ('it', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('was', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('bid', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('end', 'VB', 'O'),
#   ('urban', 'JJ', 'O'),
#   ('crime', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Separately', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('an', 'DT', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('court', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('sentenced', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('woman', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('three', 'CD', 'O'),
#   ('years', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('prison', 'NN', 'O'),
#   ('after', 'IN', 'O'),
#   ('she', 'PRP', 'O'),
#   ('pleaded', 'VBD', 'O'),
#   ('guilty', 'JJ', 'O'),
#   ('to', 'TO', 'O'),
#   ('collaborating', 'VBG', 'O'),
#   ('with', 'IN', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('militants', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('scandal', 'NN', 'O'),
#   ('broke', 'VBD', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('when', 'WRB', 'O'),
#   ('the', 'DT', 'O'),
#   ('newspaper', 'NN', 'O'),
#   ('Bild', 'NNP', 'B-per'),
#   ('printed', 'VBD', 'O'),
#   ('several', 'JJ', 'O'),
#   ('pictures', 'NNS', 'O'),
#   ('reportedly', 'RB', 'O'),
#   ('taken', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('2003', 'CD', 'B-tim'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('one', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('German', 'JJ', 'B-gpe'),
#   ('soldier', 'NN', 'O'),
#   ('posing', 'VBG', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('skull', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('sexual', 'JJ', 'O'),
#   ('manner', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('military', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('three', 'CD', 'O'),
#   ('more', 'JJR', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('service', 'NN', 'O'),
#   ('members', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Lieutenant', 'NNP', 'O'),
#   ('Dennis', 'NNP', 'B-per'),
#   ('van', 'NNP', 'I-per'),
#   ('Uhm', 'NNP', 'I-per'),
#   ('was', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('two', 'CD', 'O'),
#   ('soldiers', 'NNS', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('attack', 'NN', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('police', 'NN', 'O'),
#   ('chief', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('traveling', 'VBG', 'O'),
#   ('near', 'IN', 'O'),
#   ('Mosul', 'NNP', 'B-geo'),
#   ('when', 'WRB', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('fired', 'VBD', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('motorcade', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Japan', 'NNP', 'B-geo'),
#   ('says', 'VBZ', 'O'),
#   ('it', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('deliver', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('second', 'JJ', 'O'),
#   ('installment', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('food', 'NN', 'O'),
#   ('aid', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('North', 'NNP', 'B-geo'),
#   ('Korea', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('despite', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('disappointment', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('recent', 'JJ', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('fate', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Japanese', 'JJ', 'B-gpe'),
#   ('nationals', 'NNS', 'O'),
#   ('kidnapped', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('Pyongyang', 'NNP', 'B-tim'),
#   ('decades', 'NNS', 'I-tim'),
#   ('ago', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('New', 'JJ', 'O'),
#   ('studies', 'NNS', 'O'),
#   ('by', 'IN', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('and', 'CC', 'O'),
#   ('French', 'JJ', 'B-gpe'),
#   ('researchers', 'NNS', 'O'),
#   ('show', 'VBP', 'O'),
#   ('quick', 'JJ', 'O'),
#   ('treatment', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('minor', 'JJ', 'O'),
#   ('strokes', 'NNS', 'O'),
#   ('can', 'MD', 'O'),
#   ('dramatically', 'RB', 'O'),
#   ('cut', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('risk', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('major', 'JJ', 'O'),
#   ('strokes', 'NNS', 'O'),
#   ('later', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('expresses', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('European', 'NNP', 'B-org'),
#   ('Commission', 'NNP', 'I-org'),
#   ("'s", 'POS', 'O'),
#   ('concern', 'NN', 'O'),
#   ('about', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('situation', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('EU', 'NNP', 'B-org'),
#   ('top', 'JJ', 'O'),
#   ('executive', 'NN', 'O'),
#   ('body', 'NN', 'O'),
#   ('remains', 'VBZ', 'O'),
#   ('confident', 'JJ', 'O'),
#   ('an', 'DT', 'O'),
#   ('agreement', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('reached', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('addition', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('military', 'JJ', 'O'),
#   ('training', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('troops', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('carry', 'VB', 'O'),
#   ('out', 'RP', 'O'),
#   ('humanitarian', 'JJ', 'O'),
#   ('missions', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('try', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('boost', 'VB', 'O'),
#   ('support', 'NN', 'O'),
#   ('among', 'IN', 'O'),
#   ('Jolo', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('residents', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Phil', 'NNP', 'B-per'),
#   ('Spector', 'NNP', 'I-per'),
#   ('rose', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('fame', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('1960s', 'NNS', 'B-tim'),
#   (',', ',', 'O'),
#   ('crafting', 'VBG', 'O'),
#   ('a', 'DT', 'O'),
#   ('series', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('classic', 'JJ', 'O'),
#   ('pop', 'NN', 'O'),
#   ('singles', 'VBZ', 'O'),
#   ('using', 'VBG', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('"', '``', 'O'),
#   ('Wall', 'NNP', 'O'),
#   ('of', 'IN', 'O'),
#   ('Sound', 'NNP', 'O'),
#   ('"', '``', 'O'),
#   ('production', 'NN', 'O'),
#   ('technique', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Bloomberg', 'NNP', 'B-org'),
#   ('Financial', 'NNP', 'I-org'),
#   ('News', 'NNP', 'I-org'),
#   ('service', 'NN', 'O'),
#   ('reports', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('ExxonMobil', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('annual', 'JJ', 'O'),
#   ('sales', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('larger', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('gross', 'JJ', 'O'),
#   ('domestic', 'JJ', 'O'),
#   ('product', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('some', 'DT', 'O'),
#   ('significant', 'JJ', 'O'),
#   ('nations', 'NNS', 'O'),
#   ('like', 'IN', 'O'),
#   ('Sweden', 'NNP', 'B-geo'),
#   ('or', 'CC', 'O'),
#   ('Indonesia', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Three', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('wounded', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('ceremony', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('held', 'VBN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Kennedy', 'NNP', 'B-org'),
#   ('Space', 'NNP', 'I-org'),
#   ('Center', 'NNP', 'I-org'),
#   ('in', 'IN', 'O'),
#   ('Cape', 'NNP', 'B-geo'),
#   ('Canaveral', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('Florida', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Challenger', 'NNP', 'B-org'),
#   ('was', 'VBD', 'O'),
#   ('launched', 'VBN', 'O'),
#   ('January', 'NNP', 'B-tim'),
#   ('28', 'CD', 'I-tim'),
#   (',', ',', 'I-tim'),
#   ('1986', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('epicenter', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('quake', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('about', 'IN', 'O'),
#   ('90', 'CD', 'O'),
#   ('kilometers', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('Zhaotong', 'NNP', 'B-geo'),
#   ('city', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Brazilian', 'JJ', 'B-gpe'),
#   ('Ambassador', 'NN', 'O'),
#   ('Ronaldo', 'NNP', 'B-per'),
#   ('Sardenberg', 'NNP', 'I-per'),
#   ('is', 'VBZ', 'O'),
#   ('leading', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('delegation', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('arrived', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('Port-au-Prince', 'NNP', 'B-geo'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('four-day', 'JJ', 'B-tim'),
#   ('visit', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Hezbollah', 'NNP', 'B-org'),
#   ('says', 'VBZ', 'O'),
#   ('it', 'PRP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('destroyed', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('tanks', 'NNS', 'O'),
#   ('so', 'RB', 'O'),
#   ('far', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('Meanwhile', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('China', 'NNP', 'B-geo'),
#   ('has', 'VBZ', 'O'),
#   ('reported', 'VBN', 'O'),
#   ('two', 'CD', 'O'),
#   ('new', 'JJ', 'O'),
#   ('outbreaks', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('bird', 'NN', 'O'),
#   ('flu', 'NN', 'O'),
#   ('among', 'IN', 'O'),
#   ('poultry', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('northeastern', 'JJ', 'O'),
#   ('province', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Liaoning', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('bringing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('total', 'JJ', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('reported', 'VBN', 'O'),
#   ('outbreaks', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('past', 'JJ', 'B-tim'),
#   ('month', 'NN', 'O'),
#   ('to', 'TO', 'B-tim'),
#   ('six', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('New', 'JJ', 'O'),
#   ('fighting', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Somalia', 'NNP', 'B-gpe'),
#   ("'s", 'POS', 'O'),
#   ('capital', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('three', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('wounded', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('20', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('tests', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('suspended', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('January', 'NNP', 'B-tim'),
#   ('1996', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('On', 'IN', 'O'),
#   ('other', 'JJ', 'O'),
#   ('issues', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Latortue', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('there', 'EX', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('no', 'DT', 'O'),
#   ('doubt', 'NN', 'O'),
#   ('a', 'DT', 'O'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('held', 'VBN', 'O'),
#   ('later', 'RBR', 'B-tim'),
#   ('this', 'DT', 'O'),
#   ('year', 'NN', 'O'),
#   ('despite', 'IN', 'O'),
#   ('on-going', 'JJ', 'O'),
#   ('violence', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Interviewed', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('television', 'NN', 'O'),
#   ('program', 'NN', 'O'),
#   ('Fox', 'NNP', 'B-org'),
#   ('News', 'NNP', 'I-org'),
#   ('Sunday', 'NNP', 'B-tim'),
#   (',', ',', 'O')],
#  [('Officials', 'NNS', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('latest', 'JJS', 'O'),
#   ('infection', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('potentially', 'RB', 'O'),
#   ('deadly', 'JJ', 'O'),
#   ('H5N1', 'NNP', 'O'),
#   ('virus', 'NN', 'O'),
#   ('occurred', 'VBD', 'O'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('farm', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Mirpur', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('just', 'RB', 'O'),
#   ('outside', 'IN', 'O'),
#   ('Bangladesh', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('capital', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Dhaka', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Moscow', 'NNP', 'B-geo'),
#   ('must', 'MD', 'O'),
#   ('still', 'RB', 'O'),
#   ('negotiate', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('final', 'JJ', 'O'),
#   ('terms', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('entry', 'NN', 'O'),
#   ('into', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('trade', 'NN', 'O'),
#   ('organization', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Last', 'JJ', 'O'),
#   ('month', 'NN', 'O'),
#   ('the', 'DT', 'O'),
#   ('opposition', 'NN', 'O'),
#   ('leader', 'NN', 'O'),
#   ('met', 'VBD', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('minister', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('ruling', 'NN', 'O'),
#   ('regime', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('in', 'IN', 'O'),
#   ('September', 'NNP', 'B-tim'),
#   ('she', 'PRP', 'O'),
#   ('made', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('formal', 'JJ', 'O'),
#   ('offer', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('help', 'VB', 'O'),
#   ('negotiate', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('Western', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('lift', 'VB', 'O'),
#   ('sanctions', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Chechnya', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('Kremlin-backed', 'JJ', 'O'),
#   ('government', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('dismissed', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('purported', 'JJ', 'O'),
#   ('separatist', 'JJ', 'O'),
#   ('statement', 'NN', 'O'),
#   ('pledging', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('observe', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('ceasefire', 'NN', 'O'),
#   ('throughout', 'IN', 'O'),
#   ('this', 'DT', 'O'),
#   ('month', 'NN', 'O'),
# ...
#   ('have', 'VBP', 'O'),
#   ('established', 'VBN', 'O'),
#   ('websites', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('help', 'VB', 'O'),
#   ('people', 'NNS', 'O'),
#   ('get', 'VB', 'O'),
#   ('reunited', 'VBN', 'O'),
#   ('as', 'RB', 'O'),
#   ('quickly', 'RB', 'O'),
#   ('as', 'IN', 'O'),
#   ('possible', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('combination', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('first', 'JJ', 'O'),
#   ('time', 'NN', 'O'),
#   ('a', 'DT', 'O'),
#   ('treatment', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('recommended', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('late-stage', 'JJ', 'O'),
#   ('cervical', 'JJ', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Denver', 'NNP', 'B-org'),
#   ('quarterback', 'NN', 'O'),
#   ('Jake', 'NNP', 'B-per'),
#   ('Plummer', 'NNP', 'I-per'),
#   ('also', 'RB', 'O'),
#   ('scored', 'VBD', 'O'),
#   ('on', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('one-yard', 'JJ', 'O'),
#   ('touchdown', 'NN', 'O'),
#   ('run', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('kicker', 'NN', 'O'),
#   ('Jason', 'NNP', 'B-per'),
#   ('Elam', 'NNP', 'I-per'),
#   ('kicked', 'VBD', 'O'),
#   ('three', 'CD', 'O'),
#   ('field', 'NN', 'O'),
#   ('goals', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('As', 'IN', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('16-day', 'JJ', 'B-tim'),
#   ('mission', 'NN', 'I-tim'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('shuttle', 'NN', 'O'),
#   ('crew', 'NN', 'O'),
#   ('delivered', 'VBN', 'O'),
#   ('and', 'CC', 'O'),
#   ('installed', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('new', 'JJ', 'O'),
#   ('toilet', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('kitchen', 'NN', 'O'),
#   ('equipment', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('water', 'NN', 'O'),
#   ('recycling', 'NN', 'O'),
#   ('system', 'NN', 'O'),
#   ('meant', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('allow', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('space', 'NN', 'O'),
#   ('station', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('double', 'VB', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('crew', 'NN', 'O'),
#   ('capacity', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Officials', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   ('Jean', 'NNP', 'B-per'),
#   ('Rene', 'NNP', 'I-per'),
#   ('Anthony', 'NNP', 'I-per'),
#   ('was', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('shootout', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('police', 'NN', 'O'),
#   ('near', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('capital', 'NN', 'O'),
#   ('city', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Port-au-Prince', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('finance', 'NN', 'O'),
#   ('minister', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Abderahmane', 'NNP', 'B-org'),
#   ('Ould', 'NNP', 'I-org'),
#   ('Hamma', 'NNP', 'I-org'),
#   ('Vezzaz', 'NNP', 'I-org'),
#   (',', ',', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   ('about', 'IN', 'O'),
#   ('10,000', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('and', 'CC', 'O'),
#   ('around', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('town', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Tintane', 'NNP', 'B-org'),
#   ('were', 'VBD', 'O'),
#   ('left', 'VBN', 'O'),
#   ('homeless', 'JJ', 'O'),
#   ('after', 'IN', 'O'),
#   ('heavy', 'JJ', 'O'),
#   ('rains', 'NNS', 'O'),
#   ('that', 'WDT', 'O'),
#   ('started', 'VBD', 'O'),
#   ('last', 'JJ', 'O'),
#   ('week', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Implementation', 'NN', 'O'),
#   ('began', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('September', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('62-year-old', 'JJ', 'O'),
#   ('defendant', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('accused', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('exporting', 'VBG', 'O'),
#   ('tons', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('chemicals', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   ('used', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('make', 'VB', 'O'),
#   ('weapons', 'NNS', 'O'),
#   ('over', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('four-year', 'JJ', 'B-tim'),
#   ('period', 'NN', 'I-tim'),
#   ('beginning', 'VBG', 'I-tim'),
#   ('in', 'IN', 'I-tim'),
#   ('1984', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('man', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('25th', 'JJ', 'B-org'),
#   ('Indonesian', 'NN', 'B-gpe'),
#   ('known', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('have', 'VB', 'O'),
#   ('died', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('bird', 'NN', 'O'),
#   ('flu', 'NN', 'O'),
#   ('since', 'IN', 'B-tim'),
#   ('2003', 'CD', 'I-tim'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('second', 'JJ', 'O'),
#   ('highest', 'JJS', 'O'),
#   ('death', 'NN', 'O'),
#   ('toll', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('any', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('after', 'IN', 'O'),
#   ('Vietnam', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Officials', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Pakistan', 'NNP', 'B-geo'),
#   ('say', 'VBP', 'O'),
#   ('suspected', 'JJ', 'O'),
#   ('pro-Taleban', 'JJ', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('an', 'DT', 'O'),
#   ('elderly', 'JJ', 'O'),
#   ('tribal', 'JJ', 'O'),
#   ('leader', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('allegedly', 'RB', 'O'),
#   ('spying', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('U.S.-led', 'JJ', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('operating', 'VBG', 'O'),
#   ('in', 'IN', 'O'),
#   ('neighboring', 'VBG', 'O'),
#   ('Afghanistan', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('son', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('professional', 'JJ', 'O'),
#   ('wrestler', 'NN', 'O'),
#   ('Hulk', 'NNP', 'B-per'),
#   ('Hogan', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('released', 'VBN', 'O'),
#   ('from', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('Florida', 'NNP', 'B-geo'),
#   ('hospital', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('after', 'IN', 'O'),
#   ('being', 'VBG', 'O'),
#   ('involved', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('August', 'NNP', 'B-tim'),
#   ('26', 'CD', 'I-tim'),
#   ('car', 'NN', 'O'),
#   ('crash', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Japanese', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Junichiro', 'NNP', 'I-per'),
#   ('Koizumi', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('push', 'VB', 'O'),
#   ('ahead', 'RB', 'O'),
#   ('with', 'IN', 'O'),
#   ('plans', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('privatize', 'VB', 'O'),
#   ('Japan', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('postal', 'JJ', 'O'),
#   ('service', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('despite', 'IN', 'O'),
#   ('growing', 'VBG', 'O'),
#   ('resistance', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('some', 'DT', 'O'),
#   ('members', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('ruling', 'VBG', 'O'),
#   ('party', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Lahore', 'NNP', 'B-org'),
#   ('High', 'NNP', 'I-org'),
#   ('Court', 'NNP', 'I-org'),
#   ('on', 'IN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('ordered', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('restore', 'VB', 'O'),
#   ('access', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('Facebook', 'NNP', 'B-art'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('said', 'VBD', 'O'),
#   ('"', '``', 'O'),
#   ('blasphemous', 'JJ', 'O'),
#   ('"', '``', 'O'),
#   ('content', 'NN', 'O'),
#   ('should', 'MD', 'O'),
#   ('remain', 'VB', 'O'),
#   ('blocked', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('statement', 'NN', 'O'),
#   ('released', 'VBN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('ayatollah', 'NN', 'O'),
#   ('called', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('failure', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('security', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('decrease', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('violence', 'NN', 'O'),
#   ('plaguing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('"', '``', 'O'),
#   ('serious', 'JJ', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('Niger', 'NNP', 'B-gpe'),
#   ("'s", 'POS', 'O'),
#   ('electoral', 'JJ', 'O'),
#   ('commission', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('postponed', 'VBN', 'O'),
#   ('local', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('regional', 'JJ', 'O'),
#   ('elections', 'NNS', 'O'),
#   ('scheduled', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('by', 'IN', 'O'),
#   ('three', 'CD', 'B-tim'),
#   ('days', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('citing', 'VBG', 'O'),
#   ('logistical', 'JJ', 'O'),
#   ('problems', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('well', 'RB', 'O'),
#   ('documented', 'VBN', 'O'),
#   ('that', 'IN', 'O'),
#   ('for', 'IN', 'O'),
#   ('every', 'DT', 'O'),
#   ('mile', 'NN', 'O'),
#   ('that', 'IN', 'O'),
#   ('you', 'PRP', 'O'),
#   ('jog', 'VBP', 'O'),
#   (',', ',', 'O'),
#   ('you', 'PRP', 'O'),
#   ('add', 'VBP', 'O'),
#   ('one', 'CD', 'O'),
#   ('minute', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('your', 'PRP$', 'O'),
#   ('life', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Pitcairn', 'NNP', 'B-geo'),
#   ('Island', 'NNP', 'I-geo'),
#   ('was', 'VBD', 'O'),
#   ('discovered', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('1767', 'CD', 'B-tim'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('British', 'NNS', 'B-gpe'),
#   ('and', 'CC', 'O'),
#   ('settled', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('1790', 'CD', 'B-tim'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Bounty', 'NNP', 'O'),
#   ('mutineers', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('Tahitian', 'JJ', 'O'),
#   ('companions', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Security', 'NN', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('about', 'IN', 'O'),
#   ('50', 'CD', 'O'),
#   ('police', 'NN', 'O'),
#   ('officers', 'NNS', 'O'),
#   ('sealed', 'VBD', 'O'),
#   ('off', 'RP', 'O'),
#   ('the', 'DT', 'O'),
#   ('main', 'JJ', 'O'),
#   ('road', 'NN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('central', 'JJ', 'O'),
#   ('Gaza', 'NNP', 'B-geo'),
#   ('town', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Khan', 'NNP', 'B-per'),
#   ('Younis', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Three', 'CD', 'O'),
#   ('Yugoslav', 'JJ', 'B-gpe'),
#   ('military', 'JJ', 'O'),
#   ('officers', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('General', 'NNP', 'B-org'),
#   ('Mile', 'NNP', 'I-org'),
#   ('Mrksic', 'NNP', 'I-org'),
#   (',', ',', 'O'),
#   ('Captain', 'NNP', 'B-org'),
#   ('Miroslav', 'NNP', 'I-org'),
#   ('Radic', 'NNP', 'I-org'),
#   ('and', 'CC', 'O'),
#   ('Colonel', 'NNP', 'B-org'),
#   ('Veselin', 'NNP', 'I-org'),
#   ('Sljivancanin', 'NNP', 'I-org'),
#   ('face', 'NN', 'O'),
#   ('trial', 'NN', 'O'),
#   ('before', 'IN', 'O'),
#   ('The', 'DT', 'O'),
#   ('Hague', 'NNP', 'O'),
#   ('war', 'NN', 'O'),
#   ('crimes', 'NNS', 'O'),
#   ('tribunal', 'JJ', 'O'),
#   ('for', 'IN', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('role', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('deaths', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Baluyevsky', 'NNP', 'I-per'),
#   ('spoke', 'VBD', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('during', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('meeting', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Moscow', 'NNP', 'B-geo'),
#   ('with', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('Japanese', 'JJ', 'B-gpe'),
#   ('counterpart', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('visiting', 'VBG', 'O'),
#   ('Military', 'NNP', 'O'),
#   ('Chief', 'NNP', 'O'),
#   ('General', 'NNP', 'B-per'),
#   ('Hajime', 'NNP', 'I-per'),
#   ('Massaki', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Opinion', 'NN', 'O'),
#   ('polls', 'NNS', 'O'),
#   ('indicate', 'VBP', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('interest', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('trip', 'NN', 'O'),
#   ('falls', 'VBZ', 'O'),
#   ('far', 'RB', 'O'),
#   ('short', 'JJ', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('prince', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('1985', 'CD', 'B-tim'),
#   ('visit', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('first', 'JJ', 'O'),
#   ('wife', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('late', 'JJ', 'O'),
#   ('Princess', 'NNP', 'B-geo'),
#   ('Diana', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('2006', 'CD', 'B-tim'),
#   ('-', ':', 'I-tim'),
#   ('7', 'CD', 'I-tim'),
#   (',', ',', 'O'),
#   ('this', 'DT', 'O'),
#   ('task', 'NN', 'O'),
#   ('force', 'NN', 'O'),
#   ('successfully', 'RB', 'O'),
#   ('prosecuted', 'VBD', 'O'),
#   ('four', 'CD', 'O'),
#   ('cases', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('a', 'DT', 'O'),
#   ('landmark', 'NN', 'O'),
#   ('civil', 'JJ', 'O'),
#   ('case', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('UK', 'NNP', 'B-org'),
#   ('in', 'IN', 'O'),
#   ('which', 'WDT', 'O'),
#   ('former', 'JJ', 'O'),
#   ('President', 'NNP', 'B-per'),
#   ('CHILUBA', 'NNP', 'O'),
#   ('and', 'CC', 'O'),
#   ('numerous', 'JJ', 'O'),
#   ('others', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('found', 'VBN', 'O'),
#   ('liable', 'JJ', 'O'),
#   ('for', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('USD', 'NNP', 'O'),
#   ('41', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('.', '.', 'O')],
#  [('GAYOOM', 'NNP', 'B-per'),
#   ('was', 'VBD', 'O'),
#   ('defeated', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('runoff', 'NN', 'O'),
#   ('poll', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('Mohamed', 'NNP', 'B-geo'),
#   ('NASHEED', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('political', 'JJ', 'O'),
#   ('activist', 'NN', 'O'),
#   ('who', 'WP', 'O'),
#   ('had', 'VBD', 'O'),
#   ('been', 'VBN', 'O'),
#   ('jailed', 'VBN', 'O'),
#   ('several', 'JJ', 'B-tim'),
#   ('years', 'NNS', 'O'),
#   ('earlier', 'RBR', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('former', 'JJ', 'O'),
#   ('regime', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('date', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('polls', 'NNS', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('expected', 'VBN', 'O'),
#   ('this', 'DT', 'O'),
#   ('week', 'NN', 'O'),
#   ('or', 'CC', 'B-tim'),
#   ('next', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('defense', 'NN', 'O'),
#   ('lawyers', 'NNS', 'O'),
#   ('walked', 'VBD', 'O'),
#   ('out', 'RP', 'O'),
#   ('on', 'IN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('after', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('judge', 'NN', 'O'),
#   ('jailed', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('for', 'IN', 'O'),
#   ('what', 'WP', 'O'),
#   ('he', 'PRP', 'O'),
#   ('called', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('lack', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('discipline', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('wants', 'VBZ', 'O'),
#   ('to', 'TO', 'O'),
#   ('extend', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('vast', 'JJ', 'O'),
#   ('gas', 'NN', 'O'),
#   ('pipeline', 'NN', 'O'),
#   ('across', 'IN', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('America', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Afghan', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Hamid', 'NNP', 'I-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('called', 'VBD', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('Muslims', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('help', 'VB', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('country', 'NN', 'O'),
#   ('rid', 'VB', 'O'),
#   ('itself', 'PRP', 'O'),
#   ('of', 'IN', 'O'),
#   ('insurgents', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('massive', 'JJ', 'O'),
#   ('exodus', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('hundreds', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Yemenis', 'NNS', 'B-gpe'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('south', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('north', 'NN', 'O'),
#   ('contributed', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('two', 'CD', 'O'),
#   ('decades', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('hostility', 'NN', 'O'),
#   ('between', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('states', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  ...]
